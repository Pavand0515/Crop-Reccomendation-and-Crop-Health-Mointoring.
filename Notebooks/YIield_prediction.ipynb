# %%
import pandas as pd

# %%
df=pd.read_csv(r"D:\Capstone\Notebooks\raw_data\market_prices_real.csv")
df.head()
# Out:
#          State     District         Market                     Crop  \
# 0  West Bengal   Darjeeling  Siliguri APMC  Black Gram Dal(Urd Dal)
# 1    Telangana  Mahbubnagar  Achampet APMC  Black Gram Dal(Urd Dal)
# 2  West Bengal   Darjeeling  Siliguri APMC  Black Gram Dal(Urd Dal)
# 3  West Bengal   Darjeeling  Siliguri APMC  Black Gram Dal(Urd Dal)
# 4  Maharashtra         Pune      Pune APMC     Lentil(Masur)(Whole)
#
#           Variety  Grade        Date  Min_Price  Max_Price  Modal_Price  \
# 0  Black Gram Dal    FAQ  2026-03-16     9900.0    10100.0      10000.0
# 1           Local  Local  2026-03-15     8208.0     8346.0       8328.0
# 2  Black Gram Dal    FAQ  2026-03-15     9900.0    10100.0      10000.0
# 3  Black Gram Dal    FAQ  2026-03-14     9900.0    10100.0      10000.0
# 4           Other    FAQ  2026-03-14     6800.0     7600.0       7200.0
#
#    Commodity_Code  Price_Trend_30d Trend_Label  Cultivation_Cost  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Sr. No.     15 non-null     object
#  1   Crop        16 non-null     object
#  2   Area        16 non-null     float64
#  3   Production  16 non-null     float64
#  4   Yield       16 non-null     float64
# dtypes: float64(3), object(2)
# memory usage: 772.0+ bytes
